# %%
import pandas as pd
# Load the dataset
data = pd.read_csv("choleradataSetfinal.csv")

# Display the first few rows
data.head()

# Dataset shape and info
data.shape
data.info()


# Check for missing values
data.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 38 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   SerialNo                      792 non-null    int64
#  1   AgeYear                       792 non-null    int64
#  2   Kebelename                    792 non-null    object
#  3   HealthFacilityCTC             792 non-null    object
#  4   DateseenathealthfacilityM     789 non-null    object
#  5   DateofonsetofdiseaseMMD       791 non-null    object
#  6   DiagnosticTestResultPositiv   0 non-null      float64
#  7   IfYeswhere                    107 non-null    object
#  8   EpiweekDateofonset            792 non-null    int64
#  9   MonthDateofonset              792 non-null    object
#  10  YearDateofonset               792 non-null    int64
#  11  Dischargedate                 156 non-null    object
# ...

# %%
# Check Dataset Structure
# Check number of rows and columns
print("Shape of dataset:", data.shape)

# View column names
print("\nColumn names:")
print(data.columns.tolist())

# View data types and non-null values
print("\nData types and non-null counts:")
print(data.info())

# View the first 5 rows of the dataset
print("\nFirst 5 records:")
print(data.head())
# Out:
# Shape of dataset: (792, 38)
#
# Column names:
# ['SerialNo', 'AgeYear', 'Kebelename', 'HealthFacilityCTC', 'DateseenathealthfacilityM', 'DateofonsetofdiseaseMMD', 'DiagnosticTestResultPositiv', 'IfYeswhere', 'EpiweekDateofonset', 'MonthDateofonset', 'YearDateofonset', 'Dischargedate', 'CurrentaddmisionstatusAdmitt', 'sex', 'Region', 'Zone', 'District', 'Hospitalized', 'specimen_taken', 'type_diagnosis', 'Dehaydration_status', 'Disinfection', 'Wattery_Diarrhea', 'Vomiting', 'Occupation', 'water', 'Water_source', 'Contact_history', 'Travel_history', 'cases_from', 'outcome', 'outcom', 'Vaccination', 'Latrine_avalability', 'Age_category', 'symptom', 'diarrhoea', 'vomit']
#
# Data types and non-null counts:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792 entries, 0 to 791
# Data columns (total 38 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
# ...

# %%
#Check for Missing Data
# Count missing values per column
missing = data.isnull().sum()

# Display only columns with missing values
missing[missing > 0]
# Out:
# DateseenathealthfacilityM        3
# DateofonsetofdiseaseMMD          1
# DiagnosticTestResultPositiv    792
# IfYeswhere                     685
# Dischargedate                  636
# type_diagnosis                 791
# Occupation                      22
# water                            3
# Water_source                     3
# Vaccination                     18
# Latrine_avalability             30
# dtype: int64

# %%
#5.3 Exploratory Data Analysis (EDA)
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram for numeric columns
data.hist(figsize=(10,8))
plt.tight_layout()
plt.show()

# %%
print(y.value_counts())
# Out:
# outcome
# 0    725
# Name: count, dtype: int64

# %%
print(data['outcome'].unique())
# Out:
# [0]

# %%
print(y.value_counts())
# Out:
# outcome
# 0    725
# Name: count, dtype: int64

# %%
print(data['outcome'].unique())
# Out:
# [0]

# %%
# Reload dataset fresh (skip any earlier transformations)
import pandas as pd
data = pd.read_csv("choleradataSetfinal.csv")

# Look at raw outcome values
print(data['outcome'].unique())
print(data['outcome'].value_counts())
# Out:
# ['Recovered' 'Unknown ' 'Died at Community ' 'Reffered ' 'Died at CTC'
#  'Died on arrival' 'On treatment']
# outcome
# Recovered             705
# Unknown                62
# Died at Community      10
# Died at CTC             8
# On treatment            3
# Reffered                2
# Died on arrival         2
# Name: count, dtype: int64

# %%
# 5.6 Visualization and Correlation Analysis To understand inter-variable relationships, a correlation heatmap was created using the Seaborn library.Add target back to the data
heatmap_data = data_encoded.copy()
heatmap_data['outcome'] = y

# Plot correlation heatmap
plt.figure(figsize=(14,10))
sns.heatmap(heatmap_data.corr(), cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()
